# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import plotly
import os
# %config InlineBackend.figure_format = 'svg'
from pylab import rcParams
rcParams["figure.figsize"] = 8, 5

import numpy as np
import pandas as pd

# %%
results_path = '../../data/anonimized'
participants_path = '../../data/Участники anonimized.csv'

# %%
participants = pd.read_csv('../../data/Участники anonimized.csv')

# %%
participants
# Out:
#          ФИО  Пол    Роль в мероприятии
# 0      ФИО_0    0  Участник мероприятия  \
# 1      ФИО_1    1  Участник мероприятия
# 2      ФИО_2    0  Участник мероприятия
# 3      ФИО_3    0  Участник мероприятия
# 4      ФИО_4    0  Участник мероприятия
# ..       ...  ...                   ...
# 708  ФИО_708    0  Участник мероприятия
# 709  ФИО_709    1  Участник мероприятия
# 710  ФИО_710    1  Участник мероприятия
# 711  ФИО_711    0  Участник мероприятия
# 712  ФИО_712    0  Участник мероприятия
#
#                                 Список компетенций
# 0    Цифровое ПСР-Предприятие (Lean Smart Plant);   \
# 1                           Управление качеством;
# 2                           Сварочные технологии;
# 3                            Инженер-конструктор;
# 4                                       Геодезия;
# ..                                             ...
# 708                 Бетонные строительные работы;
# 709                         Управление качеством;
# ...

# %%
display(participants.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 713 entries, 0 to 712
# Data columns (total 15 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   ФИО                                     713 non-null    object
#  1   Пол                                     713 non-null    int64
#  2   Роль в мероприятии                      713 non-null    object
#  3   Список компетенций                      713 non-null    object
#  4   Должность                               635 non-null    object
#  5   Категория                               210 non-null    object
#  6   Начало трудового стажа                  565 non-null    object
#  7   Место работы                            707 non-null    object
#  8   Профессия                               178 non-null    object
#  9   Дата рождения                           505 non-null    object
# ...

# %%
participants.describe()
# Out:
#               Пол
# count  713.000000
# mean     0.218794
# std      0.413719
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      0.000000
# max      1.000000

# %%
participants['Список компетенций'].value_counts(dropna=False)
# Out:
# Список компетенций
# Управление жизненным циклом;                                              63
# Инженерное проектирование;                                                48
# Вывод из эксплуатации объектов использования атомной энергии;             32
# Управление качеством;                                                     28
# Сетевое и системное администрирование;                                    28
# Программные решения для бизнеса;                                          27
# Инженерное мышление. Каракури;                                            24
# Цифровое ПСР-Предприятие (Lean Smart Plant);                              24
# Мехатроника;                                                              22
# Охрана труда;                                                             22
# Промышленная механика и монтаж;                                           20
# Аналитический контроль;                                                   20
# ...

# %%
participants.value_counts()
# Out:
# ФИО      Пол  Роль в мероприятии    Список компетенций                                              Должность                                                         Категория                           Начало трудового стажа  Место работы                                                                                                  Профессия                                                     Дата рождения  Начало трудовой деятельности в РОСАТОМ  Образование                                          Место образования                                                                                                                                                                                                                                                                                                                                              Год оканчания  Специальность
# ...

# %%
participants['Роль в мероприятии'] == 'Участник не в оценке'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 708    False
# 709    False
# 710    False
# 711    False
# 712    False
# Name: Роль в мероприятии, Length: 713, dtype: bool

# %%
results = pd.read_csv(os.path.join(results_path, 'Электромонтаж.csv'))

# %%
results
# Out:
#      №      ФИО    Компетенция  Баллы, ед. Баллы, % Баллы по ключевым навыкам
# 0    1   ФИО_34  Электромонтаж         100    60,29                     60,29  \
# 1    2   ФИО_61  Электромонтаж         100    35,18                     35,18
# 2    3   ФИО_93  Электромонтаж         100    26,24                     26,24
# 3    4  ФИО_116  Электромонтаж         100    84,86                     84,86
# 4    5  ФИО_155  Электромонтаж         100    41,12                     41,12
# 5    6  ФИО_168  Электромонтаж         100    20,07                     20,07
# 6    7  ФИО_253  Электромонтаж         100    47,88                     47,88
# 7    8  ФИО_297  Электромонтаж         100    82,34                     82,34
# 8    9  ФИО_319  Электромонтаж         100    46,84                     46,84
# 9   10  ФИО_339  Электромонтаж         100    37,39                     37,39
# 10  11  ФИО_429  Электромонтаж         100    42,51                     42,51
# ...

# %%
results['ФИО'].str.contains('616')
# 14
# 3
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15     True
# Name: ФИО, dtype: bool

# %%
results.iloc[[3, 9, 12, 14, 15]]
# Out:
#      №      ФИО    Компетенция  Баллы, ед. Баллы, % Баллы по ключевым навыкам
# 3    4  ФИО_116  Электромонтаж         100    84,86                     84,86  \
# 9   10  ФИО_339  Электромонтаж         100    37,39                     37,39
# 12  13  ФИО_531  Электромонтаж         100     17,4                      17,4
# 14  15  ФИО_601  Электромонтаж         100    38,16                     38,16
# 15  16  ФИО_616  Электромонтаж         100    27,19                     27,19
#
#     A - Безопасность электрическая и личная  Максимальное значение Результат
# 3                                       NaN                      5       4,6  \
# 9                                       NaN                      5         5
# 12                                      NaN                      5       4,9
# 14                                      NaN                      5         5
# 15                                      NaN                      5         5
#
# ...

# %%
participants
# Out:
#          ФИО  Пол    Роль в мероприятии
# 0      ФИО_0    0  Участник мероприятия  \
# 1      ФИО_1    1  Участник мероприятия
# 2      ФИО_2    0  Участник мероприятия
# 3      ФИО_3    0  Участник мероприятия
# 4      ФИО_4    0  Участник мероприятия
# ..       ...  ...                   ...
# 708  ФИО_708    0  Участник мероприятия
# 709  ФИО_709    1  Участник мероприятия
# 710  ФИО_710    1  Участник мероприятия
# 711  ФИО_711    0  Участник мероприятия
# 712  ФИО_712    0  Участник мероприятия
#
#                                 Список компетенций
# 0    Цифровое ПСР-Предприятие (Lean Smart Plant);   \
# 1                           Управление качеством;
# 2                           Сварочные технологии;
# 3                            Инженер-конструктор;
# 4                                       Геодезия;
# ..                                             ...
# 708                 Бетонные строительные работы;
# 709                         Управление качеством;
# ...

# %%
rows = participants['Должность'].value_counts(dropna=True).index.str.lower().str.contains('токарь')

# %%
participants['Должность'].value_counts(dropna=True)[rows]
# Out:
# Должность
# Токарь                           5
# токарь                           3
# Токарь расточник 4 разряд        1
# токарь 6 р                       1
# Токарь, оператор станков с ПУ    1
# Токарь с ЧПУ                     1
# Name: count, dtype: int64

# %%
participants['Категория'].value_counts(dropna=False)
# Out:
# Категория
# NaN                                   503
# Инженер                               102
# Специалист (рабочие специальности)     91
# Студент                                 7
# Руководитель                            6
# Нет                                     4
# Name: count, dtype: int64

# %%
participants['Место работы'].value_counts(dropna=False)
# Out:
# Место работы
# "АО ""Сибирский химический комбинат"""                                                                               12
# "ФГУП ""Производственное объединение ""Маяк"""                                                                       11
# "АО ""Опытное Конструкторское Бюро Машиностроения имени И.И. Африкантова"""                                          10
# АО «Инжиниринговая компания «АЭМ-технологии»                                                                          9
# "АО ""Центральное конструкторское бюро машиностроения"""                                                              7
#                                                                                                                      ..
# ФГУП РФЯЦ ВНИИЭФ                                                                                                      1
# Озёрский Технический Колледж                                                                                          1
# ...

# %%
rows = participants['Место работы'].fillna('-').str.lower().str.contains('сибирский химический')
rows
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 708    False
# 709    False
# 710    False
# 711    False
# 712    False
# Name: Место работы, Length: 713, dtype: bool

# %%
participants[rows]
# Out:
#          ФИО  Пол    Роль в мероприятии
# 97    ФИО_97    0  Участник мероприятия  \
# 200  ФИО_200    0  Участник мероприятия
# 245  ФИО_245    0  Участник мероприятия
# 266  ФИО_266    0  Участник мероприятия
# 287  ФИО_287    0  Участник мероприятия
# 290  ФИО_290    0  Участник мероприятия
# 333  ФИО_333    0  Участник мероприятия
# 429  ФИО_429    0  Участник мероприятия
# 438  ФИО_438    0  Участник мероприятия
# 439  ФИО_439    1  Участник мероприятия
# 515  ФИО_515    0  Участник мероприятия
# 519  ФИО_519    0  Участник мероприятия
# 522  ФИО_522    0  Участник мероприятия
# 544  ФИО_544    0  Участник мероприятия
# 651  ФИО_651    0  Участник мероприятия
# 687  ФИО_687    0  Участник мероприятия
#
#                                     Список компетенций
# 97                       Информационная безопасность;   \
# 200                      Информационная безопасность;
# 245         Работы на токарных универсальных станках;
# ...
